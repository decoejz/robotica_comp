# %%
#! /usr/bin/env python
# -*- coding:utf-8 -*-

import cv2
import numpy as np
from matplotlib import pyplot as plt
import time

# Para usar o vídeo
# cap = cv2.VideoCapture('hall_box_battery_1024.mp4')

# As 3 próximas linhas são para usar a webcam
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)


def identifica_cor(frame):
    '''
    Segmenta o maior objeto cuja cor é parecida com cor_h (HUE da cor, no espaço HSV).
    '''

    # No OpenCV, o canal H vai de 0 até 179, logo cores similares ao 
    # vermelho puro (H=0) estão entre H=-8 e H=8. 
    # Veja se este intervalo de cores está bom
    frame_hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    cor_menor = np.array([0, 80, 80])#0, 80, 80
    cor_maior = np.array([11, 255, 255])#11, 255, 255
    segmentado_cor = cv2.inRange(frame_hsv, cor_menor, cor_maior)

    # Será possível limpar a imagem segmentado_cor? 
    # Pesquise: https://docs.opencv.org/trunk/d9/d61/tutorial_py_morphological_ops.html
    
    x = 15
    kernel = np.ones((x,x),np.uint8)
    segmentado_cor = cv2.erode(segmentado_cor,kernel,iterations = 1)
    
    # Encontramos os contornos na máscara e selecionamos o de maior área
    img_out, contornos, arvore = cv2.findContours(segmentado_cor.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE) 
    maior_contorno = None
    maior_contorno_area = 0


    cv2.drawContours(frame, contornos, -1, [255, 0, 255], 5)

    for cnt in contornos:
        area = cv2.contourArea(cnt)


        if area > maior_contorno_area:
            maior_contorno = cnt
            maior_contorno_area = area
    
    # Encontramos o centro do contorno fazendo a média de todos seus pontos.
    if not maior_contorno is None :
        cv2.drawContours(frame, [maior_contorno], -1, [0, 0, 255], 5)
        maior_contorno = np.reshape(maior_contorno, (maior_contorno.shape[0], 2))
        media = maior_contorno.mean(axis=0)
        media = media.astype(np.int32)
        cv2.circle(frame, tuple(media), 5, [0, 255, 0])
        
        #############Calculando a distancia#########
        #####CAIXA --- 36.5m de altura ----- 13.5cm de largura ------ 17cm de profundidade#########
        H = 36.5 #altura da caixa em cm
        L = 68.5 #distancia da caixa até a camera em cm
        h = 375 #altura da caixa em pixel
        l = (h*L)/H #calculando a distancia focal da camera
        
        y_maior = maior_contorno[:,1].max()
        y_menor = maior_contorno[:,1].min()
        h = y_maior - y_menor
        
        L = (H*l)/h
        
        print(L,'cm')
        #############Calculando a distancia#########
    else:
        media = (0, 0)
        
    cv2.imshow('', frame)
    cv2.imshow('imagem in_range', segmentado_cor)
    cv2.waitKey(1)
    
    centro = (frame.shape[0]//2, frame.shape[1]//2)
    
    return media, centro


while(True):
    # Capture frame-by-frame
    print("Novo frame")
    ret, frame = cap.read()


    img = frame.copy()

    media, centro = identifica_cor(img)

    #More drawing functions @ http://docs.opencv.org/2.4/modules/core/doc/drawing_functions.html

    # Display the resulting frame
    cv2.imshow('original',frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    print("No circles were found")
# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# (1712.5, 'cm')
# No circles were found
# Novo frame
# (1116.8478260869565, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (885.77586206896547, 'cm')
# No circles were found
# Novo frame
# (733.92857142857144, 'cm')
# No circles were found
# Novo frame
# (1351.9736842105262, 'cm')
# No circles were found
# Novo frame
# (694.25675675675677, 'cm')
# No circles were found
# Novo frame
# (658.65384615384619, 'cm')
# No circles were found
# Novo frame
# (1351.9736842105262, 'cm')
# No circles were found
# Novo frame
# (658.65384615384619, 'cm')
# No circles were found
# Novo frame
# (626.52439024390242, 'cm')
# No circles were found
# Novo frame
# (658.65384615384619, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (733.92857142857144, 'cm')
# No circles were found
# Novo frame
# (828.62903225806451, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (626.52439024390242, 'cm')
# No circles were found
# Novo frame
# (626.52439024390242, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (626.52439024390242, 'cm')
# No circles were found
# Novo frame
# (626.52439024390242, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (626.52439024390242, 'cm')
# No circles were found
# Novo frame
# (626.52439024390242, 'cm')
# No circles were found
# Novo frame
# (828.62903225806451, 'cm')
# No circles were found
# Novo frame
# (778.40909090909088, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (626.52439024390242, 'cm')
# No circles were found
# Novo frame
# (694.25675675675677, 'cm')
# No circles were found
# Novo frame
# (733.92857142857144, 'cm')
# No circles were found
# Novo frame
# (694.25675675675677, 'cm')
# No circles were found
# Novo frame
# (694.25675675675677, 'cm')
# No circles were found
# Novo frame
# (658.65384615384619, 'cm')
# No circles were found
# Novo frame
# (694.25675675675677, 'cm')
# No circles were found
# Novo frame
# (694.25675675675677, 'cm')
# No circles were found
# Novo frame
# (694.25675675675677, 'cm')
# No circles were found
# Novo frame
# (658.65384615384619, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (611.60714285714289, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (626.52439024390242, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (694.25675675675677, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (658.65384615384619, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (658.65384615384619, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (503.6764705882353, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (503.6764705882353, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (503.6764705882353, 'cm')
# No circles were found
# Novo frame
# (503.6764705882353, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (503.6764705882353, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (484.66981132075472, 'cm')
# No circles were found
# Novo frame
# (503.6764705882353, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (484.66981132075472, 'cm')
# No circles were found
# Novo frame
# (503.6764705882353, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (503.6764705882353, 'cm')
# No circles were found
# Novo frame
# (694.25675675675677, 'cm')
# No circles were found
# Novo frame
# (597.38372093023258, 'cm')
# No circles were found
# Novo frame
# (503.6764705882353, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (484.66981132075472, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (484.66981132075472, 'cm')
# No circles were found
# Novo frame
# (503.6764705882353, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (484.66981132075472, 'cm')
# No circles were found
# Novo frame
# (467.04545454545456, 'cm')
# No circles were found
# Novo frame
# (467.04545454545456, 'cm')
# No circles were found
# Novo frame
# (524.23469387755097, 'cm')
# No circles were found
# Novo frame
# (467.04545454545456, 'cm')
# No circles were found
# Novo frame
# (503.6764705882353, 'cm')
# No circles were found
# Novo frame
# (467.04545454545456, 'cm')
# No circles were found
# Novo frame
# (467.04545454545456, 'cm')
# No circles were found
# Novo frame
# (503.6764705882353, 'cm')
# No circles were found
# Novo frame
# (570.83333333333337, 'cm')
# No circles were found
# Novo frame
# (450.65789473684208, 'cm')
# No circles were found
# Novo frame
# (503.6764705882353, 'cm')
# No circles were found
# Novo frame
# (467.04545454545456, 'cm')
# No circles were found
# Novo frame
# (467.04545454545456, 'cm')
# No circles were found
# Novo frame
# (467.04545454545456, 'cm')
# No circles were found
# Novo frame
# (503.6764705882353, 'cm')
# No circles were found
# Novo frame
# (546.54255319148933, 'cm')
# No circles were found
# Novo frame
# (484.66981132075472, 'cm')
# No circles were found
# Novo frame
# (450.65789473684208, 'cm')
# No circles were found
# Novo frame
# (450.65789473684208, 'cm')
# No circles were found
# Novo frame
# (484.66981132075472, 'cm')
# No circles were found
# Novo frame
# (435.38135593220341, 'cm')
# No circles were found
# Novo frame
# (484.66981132075472, 'cm')
# No circles were found
# Novo frame
# (435.38135593220341, 'cm')
# No circles were found
# Novo frame
# (435.38135593220341, 'cm')
# No circles were found
# Novo frame
# (484.66981132075472, 'cm')
# No circles were found
# Novo frame
# (435.38135593220341, 'cm')
# No circles were found
# Novo frame
# (435.38135593220341, 'cm')
# No circles were found
# Novo frame
# (435.38135593220341, 'cm')
# No circles were found
# Novo frame
# (435.38135593220341, 'cm')
# No circles were found
# Novo frame
# (450.65789473684208, 'cm')
# No circles were found
# Novo frame
# (467.04545454545456, 'cm')
# No circles were found
# Novo frame
# (435.38135593220341, 'cm')
# No circles were found
# Novo frame
# (435.38135593220341, 'cm')
# No circles were found
# Novo frame
# (435.38135593220341, 'cm')
# No circles were found
# Novo frame
# (435.38135593220341, 'cm')
# No circles were found
# Novo frame
# (503.6764705882353, 'cm')
# No circles were found
# Novo frame
# (421.10655737704917, 'cm')
# No circles were found
# Novo frame
# (421.10655737704917, 'cm')
# No circles were found
# Novo frame
# (407.73809523809524, 'cm')
# No circles were found
# Novo frame
# (407.73809523809524, 'cm')
# No circles were found
# Novo frame
# (421.10655737704917, 'cm')
# No circles were found
# Novo frame
# (407.73809523809524, 'cm')
# No circles were found
# Novo frame
# (407.73809523809524, 'cm')
# No circles were found
# Novo frame
# (450.65789473684208, 'cm')
# No circles were found
# Novo frame
# (450.65789473684208, 'cm')
# No circles were found
# Novo frame
# (450.65789473684208, 'cm')
# No circles were found
# Novo frame
# (421.10655737704917, 'cm')
# No circles were found
# Novo frame
# (435.38135593220341, 'cm')
# No circles were found
# Novo frame
# (450.65789473684208, 'cm')
# No circles were found
# Novo frame
# (407.73809523809524, 'cm')
# No circles were found
# Novo frame
# (407.73809523809524, 'cm')
# No circles were found
# Novo frame
# (407.73809523809524, 'cm')
# No circles were found
# Novo frame
# (395.19230769230768, 'cm')
# No circles were found
# Novo frame
# (395.19230769230768, 'cm')
# No circles were found
# Novo frame
# (395.19230769230768, 'cm')
# No circles were found
# Novo frame
# (407.73809523809524, 'cm')
# No circles were found
# Novo frame
# (407.73809523809524, 'cm')
# No circles were found
# Novo frame
# (395.19230769230768, 'cm')
# No circles were found
# Novo frame
# (421.10655737704917, 'cm')
# No circles were found
# Novo frame
# (421.10655737704917, 'cm')
# No circles were found
# Novo frame
# (383.3955223880597, 'cm')
# No circles were found
# Novo frame
# (383.3955223880597, 'cm')
# No circles were found
# Novo frame
# (421.10655737704917, 'cm')
# No circles were found
# Novo frame
# (421.10655737704917, 'cm')
# No circles were found
# Novo frame
# (383.3955223880597, 'cm')
# No circles were found
# Novo frame
# (421.10655737704917, 'cm')
# No circles were found
# Novo frame
# (407.73809523809524, 'cm')
# No circles were found
# Novo frame
# (383.3955223880597, 'cm')
# No circles were found
# Novo frame
# (383.3955223880597, 'cm')
# No circles were found
# Novo frame
# (383.3955223880597, 'cm')
# No circles were found
# Novo frame
# (395.19230769230768, 'cm')
# No circles were found
# Novo frame
# (383.3955223880597, 'cm')
# No circles were found
# Novo frame
# (395.19230769230768, 'cm')
# No circles were found
# Novo frame
# (383.3955223880597, 'cm')
# No circles were found
# Novo frame
# (395.19230769230768, 'cm')
# No circles were found
# Novo frame
# (383.3955223880597, 'cm')
# No circles were found
# Novo frame
# (421.10655737704917, 'cm')
# No circles were found
# Novo frame
# (407.73809523809524, 'cm')
# No circles were found
# Novo frame
# (407.73809523809524, 'cm')
# No circles were found
# Novo frame
# (383.3955223880597, 'cm')
# No circles were found
# Novo frame
# (372.28260869565219, 'cm')
# No circles were found
# Novo frame
# (361.7957746478873, 'cm')
# No circles were found
# Novo frame
# (361.7957746478873, 'cm')
# No circles were found
# Novo frame
# (372.28260869565219, 'cm')
# No circles were found
# Novo frame
# (361.7957746478873, 'cm')
# No circles were found
# Novo frame
# (361.7957746478873, 'cm')
# No circles were found
# Novo frame
# (361.7957746478873, 'cm')
# No circles were found
# Novo frame
# (361.7957746478873, 'cm')
# No circles were found
# Novo frame
# (361.7957746478873, 'cm')
# No circles were found
# Novo frame
# (383.3955223880597, 'cm')
# No circles were found
# Novo frame
# (372.28260869565219, 'cm')
# No circles were found
# Novo frame
# (383.3955223880597, 'cm')
# No circles were found
# Novo frame
# (383.3955223880597, 'cm')
# No circles were found
# Novo frame
# (372.28260869565219, 'cm')
# No circles were found
# Novo frame
# (351.88356164383561, 'cm')
# No circles were found
# Novo frame
# (372.28260869565219, 'cm')
# No circles were found
# Novo frame
# (372.28260869565219, 'cm')
# No circles were found
# Novo frame
# (658.65384615384619, 'cm')
# No circles were found
# Novo frame
# (778.40909090909088, 'cm')
# No circles were found
# Novo frame
# (383.3955223880597, 'cm')
# No circles were found
# Novo frame
# (372.28260869565219, 'cm')
# No circles were found
# Novo frame
# (361.7957746478873, 'cm')
# No circles were found
# Novo frame
# (383.3955223880597, 'cm')
# No circles were found
# Novo frame
# (342.5, 'cm')
# No circles were found
# Novo frame
# (372.28260869565219, 'cm')
# No circles were found
# Novo frame
# (372.28260869565219, 'cm')
# No circles were found
# Novo frame
# (361.7957746478873, 'cm')
# No circles were found
# Novo frame
# (361.7957746478873, 'cm')
# No circles were found
# Novo frame
# (361.7957746478873, 'cm')
# No circles were found
# Novo frame
# (342.5, 'cm')
# No circles were found
# Novo frame
# (342.5, 'cm')
# No circles were found
# Novo frame
# (342.5, 'cm')
# No circles were found
# Novo frame
# (342.5, 'cm')
# No circles were found
# Novo frame
# (333.60389610389609, 'cm')
# No circles were found
# Novo frame
# (333.60389610389609, 'cm')
# No circles were found
# Novo frame
# (361.7957746478873, 'cm')
# No circles were found
# Novo frame
# (351.88356164383561, 'cm')
# No circles were found
# Novo frame
# (351.88356164383561, 'cm')
# No circles were found
# Novo frame
# (351.88356164383561, 'cm')
# No circles were found
# Novo frame
# (467.04545454545456, 'cm')
# No circles were found
# Novo frame
# (351.88356164383561, 'cm')
# No circles were found
# Novo frame
# (351.88356164383561, 'cm')
# No circles were found
# Novo frame
# (342.5, 'cm')
# No circles were found
# Novo frame
# (342.5, 'cm')
# No circles were found
# Novo frame
# (342.5, 'cm')
# No circles were found
# Novo frame
# (333.60389610389609, 'cm')
# No circles were found
# Novo frame
# (342.5, 'cm')
# No circles were found
# Novo frame
# (342.5, 'cm')
# No circles were found
# Novo frame
# (342.5, 'cm')
# No circles were found
# Novo frame
# (333.60389610389609, 'cm')
# No circles were found
# Novo frame
# (333.60389610389609, 'cm')
# No circles were found
# Novo frame
# (333.60389610389609, 'cm')
# No circles were found
# Novo frame
# (309.48795180722891, 'cm')
# No circles were found
# Novo frame
# (317.12962962962962, 'cm')
# No circles were found
# Novo frame
# (317.12962962962962, 'cm')
# No circles were found
# Novo frame
# (309.48795180722891, 'cm')
# No circles were found
# Novo frame
# (302.20588235294116, 'cm')
# No circles were found
# Novo frame
# (302.20588235294116, 'cm')
# No circles were found
# Novo frame
# (317.12962962962962, 'cm')
# No circles were found
# Novo frame
# (302.20588235294116, 'cm')
# No circles were found
# Novo frame
# (302.20588235294116, 'cm')
# No circles were found
# Novo frame
# (295.25862068965517, 'cm')
# No circles were found
# Novo frame
# (295.25862068965517, 'cm')
# No circles were found
# Novo frame
# (295.25862068965517, 'cm')
# No circles were found
# Novo frame
# (309.48795180722891, 'cm')
# No circles were found
# Novo frame
# (309.48795180722891, 'cm')
# No circles were found
# Novo frame
# (309.48795180722891, 'cm')
# No circles were found
# Novo frame
# (309.48795180722891, 'cm')
# No circles were found
# Novo frame
# (309.48795180722891, 'cm')
# No circles were found
# Novo frame
# (317.12962962962962, 'cm')
# No circles were found
# Novo frame
# (302.20588235294116, 'cm')
# No circles were found
# Novo frame
# (309.48795180722891, 'cm')
# No circles were found
# Novo frame
# (309.48795180722891, 'cm')
# No circles were found
# Novo frame
# (288.62359550561797, 'cm')
# No circles were found
# Novo frame
# (288.62359550561797, 'cm')
# No circles were found
# Novo frame
# (302.20588235294116, 'cm')
# No circles were found
# Novo frame
# (295.25862068965517, 'cm')
# No circles were found
# Novo frame
# (295.25862068965517, 'cm')
# No circles were found
# Novo frame
# (295.25862068965517, 'cm')
# No circles were found
# Novo frame
# (295.25862068965517, 'cm')
# No circles were found
# Novo frame
# (282.2802197802198, 'cm')
# No circles were found
# Novo frame
# (282.2802197802198, 'cm')
# No circles were found
# Novo frame
# (276.20967741935482, 'cm')
# No circles were found
# Novo frame
# (288.62359550561797, 'cm')
# No circles were found
# Novo frame
# (270.39473684210526, 'cm')
# No circles were found
# Novo frame
# (282.2802197802198, 'cm')
# No circles were found
# Novo frame
# (270.39473684210526, 'cm')
# No circles were found
# Novo frame
# (282.2802197802198, 'cm')
# No circles were found
# Novo frame
# (276.20967741935482, 'cm')
# No circles were found
# Novo frame
# (276.20967741935482, 'cm')
# No circles were found
# Novo frame
# (264.81958762886597, 'cm')
# No circles were found
# Novo frame
# (270.39473684210526, 'cm')
# No circles were found
# Novo frame
# (259.469696969697, 'cm')
# No circles were found
# Novo frame
# (254.33168316831683, 'cm')
# No circles were found
# Novo frame
# (259.469696969697, 'cm')
# No circles were found
# Novo frame
# (273.27127659574467, 'cm')
# No circles were found
# Novo frame
# (254.33168316831683, 'cm')
# No circles were found
# Novo frame
# (254.33168316831683, 'cm')
# No circles were found
# Novo frame
# (254.33168316831683, 'cm')
# No circles were found
# Novo frame
# (249.39320388349515, 'cm')
# No circles were found
# Novo frame
# (249.39320388349515, 'cm')
# No circles were found
# Novo frame
# (259.469696969697, 'cm')
# No circles were found
# Novo frame
# (259.469696969697, 'cm')
# No circles were found
# Novo frame
# (254.33168316831683, 'cm')
# No circles were found
# Novo frame
# (254.33168316831683, 'cm')
# No circles were found
# Novo frame
# (254.33168316831683, 'cm')
# No circles were found
# Novo frame
# (249.39320388349515, 'cm')
# No circles were found
# Novo frame
# (249.39320388349515, 'cm')
# No circles were found
# Novo frame
# (249.39320388349515, 'cm')
# No circles were found
# Novo frame
# (249.39320388349515, 'cm')
# No circles were found
# Novo frame
# (244.64285714285714, 'cm')
# No circles were found
# Novo frame
# (215.86134453781511, 'cm')
# No circles were found
# Novo frame
# (240.07009345794393, 'cm')
# No circles were found
# Novo frame
# (227.32300884955751, 'cm')
# No circles were found
# Novo frame
# (227.32300884955751, 'cm')
# No circles were found
# Novo frame
# (235.66513761467891, 'cm')
# No circles were found
# Novo frame
# (235.66513761467891, 'cm')
# No circles were found
# Novo frame
# (235.66513761467891, 'cm')
# No circles were found
# Novo frame
# (235.66513761467891, 'cm')
# No circles were found
# Novo frame
# (231.41891891891891, 'cm')
# No circles were found
# Novo frame
# (231.41891891891891, 'cm')
# No circles were found
# Novo frame
# (235.66513761467891, 'cm')
# No circles were found
# Novo frame
# (231.41891891891891, 'cm')
# No circles were found
# Novo frame
# (227.32300884955751, 'cm')
# No circles were found
# Novo frame
# (219.55128205128204, 'cm')
# No circles were found
# Novo frame
# (231.41891891891891, 'cm')
# No circles were found
# Novo frame
# (264.81958762886597, 'cm')
# No circles were found
# Novo frame
# (231.41891891891891, 'cm')
# No circles were found
# Novo frame
# (215.86134453781511, 'cm')
# No circles were found
# Novo frame
# (227.32300884955751, 'cm')
# No circles were found
# Novo frame
# (361.7957746478873, 'cm')
# No circles were found
# Novo frame
# (309.48795180722891, 'cm')
# No circles were found
# Novo frame
# (227.32300884955751, 'cm')
# No circles were found
# Novo frame
# (223.36956521739131, 'cm')
# No circles were found
# Novo frame
# (219.55128205128204, 'cm')
# No circles were found
# Novo frame
# (219.55128205128204, 'cm')
# No circles were found
# Novo frame
# (219.55128205128204, 'cm')
# No circles were found
# Novo frame
# (212.29338842975207, 'cm')
# No circles were found
# Novo frame
# (212.29338842975207, 'cm')
# No circles were found
# Novo frame
# (212.29338842975207, 'cm')
# No circles were found
# Novo frame
# (208.84146341463415, 'cm')
# No circles were found
# Novo frame
# (208.84146341463415, 'cm')
# No circles were found
# Novo frame
# (205.5, 'cm')
# No circles were found
# Novo frame
# (208.84146341463415, 'cm')
# No circles were found
# Novo frame
# (223.36956521739131, 'cm')
# No circles were found
# Novo frame
# (202.26377952755905, 'cm')
# No circles were found
# Novo frame
# (199.12790697674419, 'cm')
# No circles were found
# Novo frame
# (193.1390977443609, 'cm')
# No circles were found
# Novo frame
# (199.12790697674419, 'cm')
# No circles were found
# Novo frame
# (196.08778625954199, 'cm')
# No circles were found
# Novo frame
# (193.1390977443609, 'cm')
# No circles were found
# Novo frame
# (193.1390977443609, 'cm')
# No circles were found
# Novo frame
# (190.27777777777777, 'cm')
# No circles were found
# Novo frame
# (187.5, 'cm')
# No circles were found
# Novo frame
# (190.27777777777777, 'cm')
# No circles were found
# Novo frame
# (190.27777777777777, 'cm')
# No circles were found
# Novo frame
# (190.27777777777777, 'cm')
# No circles were found
# Novo frame
# (187.5, 'cm')
# No circles were found
# Novo frame
# (187.5, 'cm')
# No circles were found
# Novo frame
# (190.27777777777777, 'cm')
# No circles were found
# Novo frame
# (187.5, 'cm')
# No circles were found
# Novo frame
# (184.80215827338131, 'cm')
# No circles were found
# Novo frame
# (184.80215827338131, 'cm')
# No circles were found
# Novo frame
# (177.15517241379311, 'cm')
# No circles were found
# Novo frame
# (179.63286713286712, 'cm')
# No circles were found
# Novo frame
# (172.3993288590604, 'cm')
# No circles were found
# Novo frame
# (174.74489795918367, 'cm')
# No circles were found
# Novo frame
# (167.89215686274511, 'cm')
# No circles were found
# Novo frame
# (172.3993288590604, 'cm')
# No circles were found
# Novo frame
# (170.11589403973511, 'cm')
# No circles were found
# Novo frame
# (174.74489795918367, 'cm')
# No circles were found
# Novo frame
# (172.3993288590604, 'cm')
# No circles were found
# Novo frame
# (174.74489795918367, 'cm')
# No circles were found
# Novo frame
# (150.21929824561403, 'cm')
# No circles were found
# Novo frame
# (155.68181818181819, 'cm')
# No circles were found
# Novo frame
# (170.11589403973511, 'cm')
# No circles were found
# Novo frame
# (155.68181818181819, 'cm')
# No circles were found
# Novo frame
# (161.5566037735849, 'cm')
# No circles were found
# Novo frame
# (163.61464968152868, 'cm')
# No circles were found
# Novo frame
# (151.99704142011834, 'cm')
# No circles were found
# Novo frame
# (163.61464968152868, 'cm')
# No circles were found
# Novo frame
# (153.81736526946108, 'cm')
# No circles were found
# Novo frame
# (153.81736526946108, 'cm')
# No circles were found
# Novo frame
# (153.81736526946108, 'cm')
# No circles were found
# Novo frame
# (153.81736526946108, 'cm')
# No circles were found
# Novo frame
# (146.78571428571428, 'cm')
# No circles were found
# Novo frame
# (150.21929824561403, 'cm')
# No circles were found
# Novo frame
# (148.48265895953756, 'cm')
# No circles were found
# Novo frame
# (156.6310975609756, 'cm')
# No circles were found
# Novo frame
# (147.62931034482759, 'cm')
# No circles were found
# Novo frame
# (143.50558659217876, 'cm')
# No circles were found
# Novo frame
# (151.99704142011834, 'cm')
# No circles were found
# Novo frame
# (138.85135135135135, 'cm')
# No circles were found
# Novo frame
# (150.21929824561403, 'cm')
# No circles were found
# Novo frame
# (148.48265895953756, 'cm')
# No circles were found
# Novo frame
# (148.48265895953756, 'cm')
# No circles were found
# Novo frame
# (145.12711864406779, 'cm')
# No circles were found
# Novo frame
# (145.12711864406779, 'cm')
# No circles were found
# Novo frame
# (131.05867346938774, 'cm')
# No circles were found
# Novo frame
# (137.36631016042782, 'cm')
# No circles were found
# Novo frame
# (135.9126984126984, 'cm')
# No circles were found
# Novo frame
# (140.36885245901638, 'cm')
# No circles were found
# Novo frame
# (129.08291457286433, 'cm')
# No circles were found
# Novo frame
# (130.39340101522842, 'cm')
# No circles were found
# Novo frame
# (133.09585492227978, 'cm')
# No circles were found
# Novo frame
# (135.9126984126984, 'cm')
# No circles were found
# Novo frame
# (135.9126984126984, 'cm')
# No circles were found
# Novo frame
# (131.73076923076923, 'cm')
# No circles were found
# Novo frame
# (134.48952879581151, 'cm')
# No circles were found
# Novo frame
# (134.48952879581151, 'cm')
# No circles were found
# Novo frame
# (133.09585492227978, 'cm')
# No circles were found
# Novo frame
# (131.73076923076923, 'cm')
# No circles were found
# Novo frame
# (133.09585492227978, 'cm')
# No circles were found
# Novo frame
# (131.73076923076923, 'cm')
# No circles were found
# Novo frame
# (127.79850746268657, 'cm')
# No circles were found
# Novo frame
# (129.08291457286433, 'cm')
# No circles were found
# Novo frame
# (129.08291457286433, 'cm')
# No circles were found
# Novo frame
# (130.39340101522842, 'cm')
# No circles were found
# Novo frame
# (129.08291457286433, 'cm')
# No circles were found
# Novo frame
# (127.79850746268657, 'cm')
# No circles were found
# Novo frame
# (126.53940886699507, 'cm')
# No circles were found
# Novo frame
# (125.30487804878049, 'cm')
# No circles were found
# Novo frame
# (125.30487804878049, 'cm')
# No circles were found
# Novo frame
# (125.30487804878049, 'cm')
# No circles were found
# Novo frame
# (124.09420289855072, 'cm')
# No circles were found
# Novo frame
# (124.09420289855072, 'cm')
# No circles were found
# Novo frame
# (122.9066985645933, 'cm')
# No circles were found
# Novo frame
# (124.09420289855072, 'cm')
# No circles were found
# Novo frame
# (121.74170616113744, 'cm')
# No circles were found
# Novo frame
# (119.47674418604652, 'cm')
# No circles were found
# Novo frame
# (119.47674418604652, 'cm')
# No circles were found
# Novo frame
# (119.47674418604652, 'cm')
# No circles were found
# Novo frame
# (119.47674418604652, 'cm')
# No circles were found
# Novo frame
# (120.59859154929578, 'cm')
# No circles were found
# Novo frame
# (119.47674418604652, 'cm')
# No circles were found
# Novo frame
# (117.29452054794521, 'cm')
# No circles were found
# Novo frame
# (111.2012987012987, 'cm')
# No circles were found
# Novo frame
# (112.17248908296943, 'cm')
# No circles were found
# Novo frame
# (115.19058295964126, 'cm')
# No circles were found
# Novo frame
# (117.29452054794521, 'cm')
# No circles were found
# Novo frame
# (115.19058295964126, 'cm')
# No circles were found
# Novo frame
# (111.2012987012987, 'cm')
# No circles were found
# Novo frame
# (116.23303167420815, 'cm')
# No circles were found
# Novo frame
# (115.19058295964126, 'cm')
# No circles were found
# Novo frame
# (115.19058295964126, 'cm')
# No circles were found
# Novo frame
# (114.16666666666667, 'cm')
# No circles were found
# Novo frame
# (114.16666666666667, 'cm')
# No circles were found
# Novo frame
# (114.16666666666667, 'cm')
# No circles were found
# Novo frame
# (114.16666666666667, 'cm')
# No circles were found
# Novo frame
# (114.16666666666667, 'cm')
# No circles were found
# Novo frame
# (111.2012987012987, 'cm')
# No circles were found
# Novo frame
# (109.30851063829788, 'cm')
# No circles were found
# Novo frame
# (109.30851063829788, 'cm')
# No circles were found
# Novo frame
# (107.47907949790795, 'cm')
# No circles were found
# Novo frame
# (113.16079295154185, 'cm')
# No circles were found
# Novo frame
# (112.17248908296943, 'cm')
# No circles were found
# Novo frame
# (109.30851063829788, 'cm')
# No circles were found
# Novo frame
# (112.17248908296943, 'cm')
# No circles were found
# Novo frame
# (112.17248908296943, 'cm')
# No circles were found
# Novo frame
# (115.19058295964126, 'cm')
# No circles were found
# Novo frame
# (115.19058295964126, 'cm')
# No circles were found
# Novo frame
# (116.23303167420815, 'cm')
# No circles were found
# Novo frame
# (117.29452054794521, 'cm')
# No circles were found
# Novo frame
# (114.16666666666667, 'cm')
# No circles were found
# Novo frame
# (114.16666666666667, 'cm')
# No circles were found
# Novo frame
# (115.19058295964126, 'cm')
# No circles were found
# Novo frame
# (114.16666666666667, 'cm')
# No circles were found
# Novo frame
# (116.23303167420815, 'cm')
# No circles were found
# Novo frame
# (114.16666666666667, 'cm')
# No circles were found
# Novo frame
# (114.16666666666667, 'cm')
# No circles were found
# Novo frame
# (116.23303167420815, 'cm')
# No circles were found
# Novo frame
# (117.29452054794521, 'cm')
# No circles were found
# Novo frame
# (118.37557603686636, 'cm')
# No circles were found
# Novo frame
# (115.19058295964126, 'cm')
# No circles were found
# Novo frame
# (115.19058295964126, 'cm')
# No circles were found
# Novo frame
# (117.29452054794521, 'cm')
# No circles were found
# Novo frame
# (116.23303167420815, 'cm')
# No circles were found
# Novo frame
# (118.37557603686636, 'cm')
# No circles were found
# Novo frame
# (117.29452054794521, 'cm')
# No circles were found
# Novo frame
# (113.66150442477876, 'cm')
# No circles were found
# Novo frame
# (113.16079295154185, 'cm')
# No circles were found
# Novo frame
# (116.23303167420815, 'cm')
# No circles were found
# Novo frame
# (117.29452054794521, 'cm')
# No circles were found
# Novo frame
# (119.47674418604652, 'cm')
# No circles were found
# Novo frame
# (117.29452054794521, 'cm')
# No circles were found
# Novo frame
# (118.37557603686636, 'cm')
# No circles were found
# Novo frame
# (117.29452054794521, 'cm')
# No circles were found
# Novo frame
# (118.37557603686636, 'cm')
# No circles were found
# Novo frame
# (116.23303167420815, 'cm')
# No circles were found
# Novo frame
# (116.23303167420815, 'cm')
# No circles were found
# Novo frame
# (117.29452054794521, 'cm')
# No circles were found
# Novo frame
# (119.47674418604652, 'cm')
# No circles were found
# Novo frame
# (114.16666666666667, 'cm')
# No circles were found
# Novo frame
# (118.37557603686636, 'cm')
# No circles were found
# Novo frame
# (119.47674418604652, 'cm')
# No circles were found
# Novo frame
# (115.19058295964126, 'cm')
# No circles were found
# Novo frame
# (115.19058295964126, 'cm')
# No circles were found
# Novo frame
# (119.47674418604652, 'cm')
# No circles were found
# Novo frame
# (120.59859154929578, 'cm')
# No circles were found
# Novo frame
# (119.47674418604652, 'cm')
# No circles were found
# Novo frame
# (118.37557603686636, 'cm')
# No circles were found
# Novo frame
# (117.29452054794521, 'cm')
# No circles were found
# Novo frame
# (119.47674418604652, 'cm')
# No circles were found
# Novo frame
# (115.19058295964126, 'cm')
# No circles were found
# Novo frame
# (118.37557603686636, 'cm')
# No circles were found
# Novo frame
# (118.37557603686636, 'cm')
# No circles were found
# Novo frame
# (115.19058295964126, 'cm')
# No circles were found
# Novo frame
# (118.37557603686636, 'cm')
# No circles were found
# Novo frame
# (114.16666666666667, 'cm')
# No circles were found
# Novo frame
# (117.29452054794521, 'cm')
# No circles were found
# Novo frame
# (118.37557603686636, 'cm')
# No circles were found
# Novo frame
# (117.29452054794521, 'cm')
# No circles were found
# Novo frame
# (113.16079295154185, 'cm')
# No circles were found
# Novo frame
# (113.16079295154185, 'cm')
# No circles were found
# Novo frame
# (113.16079295154185, 'cm')
# No circles were found
# Novo frame
# (112.17248908296943, 'cm')
# No circles were found
# Novo frame
# (114.16666666666667, 'cm')
# No circles were found
# Novo frame
# (112.17248908296943, 'cm')
# No circles were found
# Novo frame
# (113.16079295154185, 'cm')
# No circles were found
# Novo frame
# (111.68478260869566, 'cm')
# No circles were found
# Novo frame
# (108.38607594936708, 'cm')
# No circles were found
# Novo frame
# (107.03125, 'cm')
# No circles were found
# Novo frame
# (106.58713692946058, 'cm')
# No circles were found
# Novo frame
# (111.2012987012987, 'cm')
# No circles were found
# Novo frame
# (115.19058295964126, 'cm')
# No circles were found
# Novo frame
# (112.17248908296943, 'cm')
# No circles were found
# Novo frame
# (111.2012987012987, 'cm')
# No circles were found
# Novo frame
# (115.19058295964126, 'cm')
# No circles were found
# Novo frame
# (112.17248908296943, 'cm')
# No circles were found
# Novo frame
# (115.70945945945945, 'cm')
# No circles were found
# Novo frame
# (114.67633928571429, 'cm')
# No circles were found
# Novo frame
# (113.16079295154185, 'cm')
# No circles were found
# Novo frame
# (113.66150442477876, 'cm')
# No circles were found
# Novo frame
# (112.17248908296943, 'cm')
# No circles were found
# Novo frame
# (111.68478260869566, 'cm')
# No circles were found
# Novo frame
# (114.67633928571429, 'cm')
# No circles were found
# Novo frame
# (112.17248908296943, 'cm')
# No circles were found
# Novo frame
# (110.24678111587983, 'cm')
# No circles were found
# Novo frame
# (110.72198275862068, 'cm')
# No circles were found
# Novo frame
# (109.30851063829788, 'cm')
# No circles were found
# Novo frame
# (109.30851063829788, 'cm')
# No circles were found
# Novo frame
# (107.03125, 'cm')
# No circles were found
# Novo frame
# (106.14669421487604, 'cm')
# No circles were found
# Novo frame
# (103.16265060240964, 'cm')
# No circles were found
# Novo frame
# (103.16265060240964, 'cm')
# No circles were found
# Novo frame
# (103.99797570850203, 'cm')
# No circles were found
# Novo frame
# (104.84693877551021, 'cm')
# No circles were found
# Novo frame
# (103.99797570850203, 'cm')
# No circles were found
# Novo frame
# (98.419540229885058, 'cm')
# No circles were found
# Novo frame
# (100.73529411764706, 'cm')
# No circles were found
# Novo frame
# (100.73529411764706, 'cm')
# No circles were found
# Novo frame
# (96.207865168539328, 'cm')
# No circles were found
# Novo frame
# (95.492565055762086, 'cm')
# No circles were found
# Novo frame
# (97.671102661596962, 'cm')
# No circles were found
# Novo frame
# (98.79807692307692, 'cm')
# No circles were found
# Novo frame
# (98.419540229885058, 'cm')
# No circles were found
# Novo frame
# (97.671102661596962, 'cm')
# No circles were found
# Novo frame
# (96.933962264150949, 'cm')
# No circles were found
# Novo frame
# (94.787822878228781, 'cm')
# No circles were found
# Novo frame
# (94.093406593406598, 'cm')
# No circles were found
# Novo frame
# (93.75, 'cm')
# No circles were found
# Novo frame
# (91.414590747330962, 'cm')
# No circles were found
# Novo frame
# (93.409090909090907, 'cm')
# No circles were found
# Novo frame
# (92.734657039711195, 'cm')
# No circles were found
# Novo frame
# (90.131578947368425, 'cm')
# No circles were found
# Novo frame
# (88.273195876288653, 'cm')
# No circles were found
# Novo frame
# (85.911371237458198, 'cm')
# No circles were found
# Novo frame
# (84.221311475409834, 'cm')
# No circles were found
# Novo frame
# (84.777227722772281, 'cm')
# No circles were found
# Novo frame
# (81.033123028391174, 'cm')
# No circles were found
# Novo frame
# (81.547619047619051, 'cm')
# No circles were found
# Novo frame
# (81.547619047619051, 'cm')
# No circles were found
# Novo frame
# (80.525078369905955, 'cm')
# No circles were found
# Novo frame
# (77.13963963963964, 'cm')
# No circles were found
# Novo frame
# (77.13963963963964, 'cm')
# No circles were found
# Novo frame
# (74.890670553935863, 'cm')
# No circles were found
# Novo frame
# (73.603151862464188, 'cm')
# No circles were found
# Novo frame
# (74.027377521613829, 'cm')
# No circles were found
# Novo frame
# (74.027377521613829, 'cm')
# No circles were found
# Novo frame
# (72.769121813031163, 'cm')
# No circles were found
# Novo frame
# (70.570054945054949, 'cm')
# No circles were found
# Novo frame
# (71.752793296089379, 'cm')
# No circles were found
# Novo frame
# (72.975852272727266, 'cm')
# No circles were found
# Novo frame
# (75.109649122807014, 'cm')
# No circles were found
# Novo frame
# (77.840909090909093, 'cm')
# No circles were found
# Novo frame
# (80.023364485981304, 'cm')
# No circles were found
# Novo frame
# (82.331730769230774, 'cm')
# No circles were found
# Novo frame
# (84.49835526315789, 'cm')
# No circles were found
# Novo frame
# (86.199664429530202, 'cm')
# No circles were found
# Novo frame
# (87.372448979591837, 'cm')
# No circles were found
# Novo frame
# (89.192708333333329, 'cm')
# No circles were found
# Novo frame
# (90.448943661971825, 'cm')
# No circles were found
# Novo frame
# (91.414590747330962, 'cm')
# No circles were found
# Novo frame
# (92.069892473118273, 'cm')
# No circles were found
# Novo frame
# (93.070652173913047, 'cm')
# No circles were found
# Novo frame
# (93.75, 'cm')
# No circles were found
# Novo frame
# (94.439338235294116, 'cm')
# No circles were found
# Novo frame
# (95.848880597014926, 'cm')
# No circles were found
# Novo frame
# (97.30113636363636, 'cm')
# No circles were found
# Novo frame
# (98.79807692307692, 'cm')
# No circles were found
# Novo frame
# (214.0625, 'cm')
# No circles were found
# Novo frame
# (102.75, 'cm')
# No circles were found
# Novo frame
# (214.0625, 'cm')
# No circles were found
# Novo frame
# (139.60597826086956, 'cm')
# No circles were found
# Novo frame
# (246.99519230769232, 'cm')
# No circles were found
# Novo frame
# (458.70535714285717, 'cm')
# No circles were found
# Novo frame
# (802.734375, 'cm')
# No circles were found
# Novo frame
# (401.3671875, 'cm')
# No circles were found
# Novo frame
# (285.41666666666669, 'cm')
# No circles were found
# Novo frame
# (611.60714285714289, 'cm')
# No circles were found
# Novo frame
# (2140.625, 'cm')
# No circles were found
# Novo frame
# (1975.9615384615386, 'cm')
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# No circles were found
# Novo frame
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-c61b2e533e41> in <module>()
#     106
#     107
# --> 108     img = frame.copy()
#     109
#     110     media, centro = identifica_cor(img)
#
# AttributeError: 'NoneType' object has no attribute 'copy'
